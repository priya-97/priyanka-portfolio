# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df=pd.read_csv('C:/Users/priyanka/Downloads/Loan_dataset.csv')

# %%
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
#1.What is the average current loan amount for each loan status?
df.groupby(by='Loan Status')['Current Loan Amount'].mean()
# Out:
# Loan Status
# Charged Off    3.249752e+05
# Fully Paid     1.510694e+07
# Name: Current Loan Amount, dtype: float64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import show

# %%
#2.How does the credit score vary with the annual income?
df[['Credit Score','Annual Income']].plot(kind='line')
# Out:
# <Axes: >

# %%
#3.Is there a correlation between the number of open accounts and the current credit balance?
sns.heatmap(df[['Number of Open Accounts','Current Credit Balance']].corr())
# Out:
# <Axes: >

# %%
#4.What is the distribution of credit scores across different home ownership types?
sns.histplot(data=df,x='Credit Score',y='Home Ownership',kde=True)
# Out:
# <Axes: xlabel='Credit Score', ylabel='Home Ownership'>

# %%
#5.How does the annual income differ for different purposes of loans?
sns.scatterplot(data=df,x='Annual Income',y='Purpose')
# Out:
# <Axes: xlabel='Annual Income', ylabel='Purpose'>

# %%
#What is the average monthly debt for each term (short-term vs. long-term)?
df.groupby(by='Term')['Monthly Debt'].mean()
# Out:
# Term
# Long Term     21585.664968
# Short Term    17274.158442
# Name: Monthly Debt, dtype: float64

# %%
#Is there a correlation between years of credit history and the current credit balance?
sns.heatmap(df[['Years of Credit History','Current Credit Balance']].corr())
# Out:
# <Axes: >

# %%
#How does the credit score vary with the years in the current job?
df[['Credit Score','Years in current job']].plot(kind='line')
# Out:
# <Axes: >

# %%
#What is the relationship between the number of credit problems and the number of open accounts?
sns.scatterplot(data=df,x='Number of Credit Problems',y='Number of Open Accounts')
# Out:
# <Axes: xlabel='Number of Credit Problems', ylabel='Number of Open Accounts'>

# %%
#What is the distribution of annual income across different loan statuses?
sns.histplot(data=df,x='Annual Income',y='Loan Status',kde=True)
# Out:
# <Axes: xlabel='Annual Income', ylabel='Loan Status'>

# %%
#Is there a correlation between the current loan amount and the number of open accounts?
sns.heatmap(df[['Number of Open Accounts','Current Loan Amount']].corr())
# Out:
# <Axes: >

# %%
#How does the monthly debt vary with the years of credit history?
df[['Years of Credit History','Monthly Debt']].plot(kind='line')
# Out:
# <Axes: >

# %%
#What is the average annual income for each purpose of loan?
df.groupby(by='Purpose')['Annual Income'].mean()
# Out:
# Purpose
# Business Loan           1.591963e+06
# Buy House               1.495251e+06
# Buy a Car               1.220353e+06
# Debt Consolidation      1.362464e+06
# Educational Expenses    1.071051e+06
# Home Improvements       1.667437e+06
# Medical Bills           1.409286e+06
# Other                   1.348516e+06
# Take a Trip             1.219899e+06
# major_purchase          1.430753e+06
# moving                  1.591375e+06
# other                   1.286008e+06
# renewable_energy        1.473740e+06
# small_business          1.547456e+06
# vacation                1.155290e+06
# wedding                 1.464233e+06
# Name: Annual Income, dtype: float64

# %%
#How does the credit score vary with the number of credit problems?
df[['Credit Score','Number of Credit Problems']].plot(kind='line')
# Out:
# <Axes: >

# %%
#Is there a correlation between the number of credit problems and the current credit balance?
sns.heatmap(df[['Number of Credit Problems','Current Credit Balance']].corr())
# Out:
# <Axes: >

# %%
#What is the distribution of current loan amounts across different home ownership types?
sns.histplot(data=df,x='Current Loan Amount',y='Home Ownership',kde=True)
# Out:
# <Axes: xlabel='Current Loan Amount', ylabel='Home Ownership'>

# %%
#How does the annual income vary with the years in the current job?
df[['Annual Income','Years in current job']].plot(kind='line')
# Out:
# <Axes: >

# %%
#Is there a correlation between the current loan amount and the monthly debt?
sns.heatmap(df[['Current Loan Amount','Monthly Debt']].corr())
# Out:
# <Axes: >

# %%
#What is the average monthly debt for each home ownership type?
df.groupby(by='Home Ownership')['Monthly Debt'].mean()
# Out:
# Home Ownership
# HaveMortgage     18541.776822
# Home Mortgage    21072.059467
# Own Home         17060.082101
# Rent             15796.777284
# Name: Monthly Debt, dtype: float64

# %%
#How does the credit score vary with the number of open accounts?
df[['Credit Score','Number of Open Accounts']].plot(kind='line')
# Out:
# <Axes: >

# %%
#What is the distribution of credit scores across different loan statuses?
sns.histplot(data=df,x='Credit Score',y='Loan Status',kde=True)
# Out:
# <Axes: xlabel='Credit Score', ylabel='Loan Status'>

# %%
#Is there a correlation between the current loan amount and the years of credit history?
sns.heatmap(df[['Current Loan Amount','Years of Credit History']].corr())
# Out:
# <Axes: >

# %%
#How does the monthly debt vary with the number of credit problems?
df[['Monthly Debt','Number of Credit Problems']].plot(kind='line')
# Out:
# <Axes: >

# %%
#What is the average current loan amount for each purpose of loan?
df.groupby(by='Purpose')['Current Loan Amount'].mean()
# Out:
# Purpose
# Business Loan           7.837789e+06
# Buy House               1.106036e+07
# Buy a Car               1.414682e+07
# Debt Consolidation      1.180683e+07
# Educational Expenses    1.428536e+07
# Home Improvements       1.252117e+07
# Medical Bills           1.179902e+07
# Other                   1.253627e+07
# Take a Trip             1.111667e+07
# major_purchase          1.298956e+07
# moving                  1.350072e+07
# other                   1.059243e+07
# renewable_energy        1.975534e+05
# small_business          9.484232e+06
# vacation                7.058680e+06
# wedding                 1.760299e+07
# Name: Current Loan Amount, dtype: float64

# %%
# How does the credit score vary with the current credit balance?
df[['Credit Score','Current Credit Balance']].plot(kind='line')
# Out:
# <Axes: >

# %%
# Is there a correlation between the annual income and the current credit balance? 
sns.heatmap(df[['Annual Income','Current Credit Balance']].corr())
# Out:
# <Axes: >

# %%
# What is the distribution of annual income across different terms (short-term vs. long-term)?
sns.histplot(data=df,x='Term',y='Annual Income',kde=True)
# Out:
# <Axes: xlabel='Term', ylabel='Annual Income'>

# %%
# What is the relationship between the number of open accounts and the years of credit history?
sns.scatterplot(data=df,x='Years of Credit History',y='Number of Open Accounts')
# Out:
# <Axes: xlabel='Years of Credit History', ylabel='Number of Open Accounts'>

# %%
#28.How does the credit score vary with the number of credit problems?
df[['Credit Score','Number of Credit Problems']].plot(kind='line')
# Out:
# <Axes: >

# %%
#Is there a correlation between the current loan amount and the number of credit problems?
sns.heatmap(df[['Current Loan Amount','Number of Credit Problems']].corr())
# Out:
# <Axes: >
